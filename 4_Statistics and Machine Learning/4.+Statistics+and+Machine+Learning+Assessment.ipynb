# %% [markdown]
# # Statistics
#
# In this assessment, we will use the Python libraries `Pandas` and `NumPy` to perform basic operations on the data relating to food hygiene in Wandsworth.  In addition we will also perform linear regression on data about vehicle mileage and price.
#
# Run the cell below each time you load the page to make sure that all the imports are done correctly

# %%
import numpy as np
import pandas as pd

from bokeh.io import output_notebook, show
from bokeh.charts import *
output_notebook()

from nose.tools import *

import pymongo
from pymongo import MongoClient
client = MongoClient('mongodb://cpduser:M13pV5woDW@mongodb/health_data', 27017)
db = client.health_data

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

print('All libraries successfully loaded')
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="723052cf-a28a-4036-af03-e201dcb89e76">Loading BokehJS ...</span>
#     </div>
# All libraries successfully loaded

# %% [markdown]
# ## Question 1: Statistics
#
# ### Question 1(a) [4 marks]
#
# Create a **function** `evaluate_random_data` which has the following **parameters**:
# - `n` the size of the Pandas `Series` you are to create
# - `evaluation` a string should say which task to perform on the `Series` object.
# - `seed` an integer which should instantiate a numpy `RandomState` instance, with a default value of 543210
#
# The function should do the following:
# - Create an array of size `n` which is full of random numbers integers between 0 and 100 (inclusive)
# - The `evaluation` should be able to perform mean, median and standard deviation functions on the created array
# - The function should **return** the output of the evaluation on the array.  It should be able to cope with `"mean"`, `"median"` and `"std"` (standard deviation).
#
# *Hint: Week 4, Guided Exercise 2, Randomness - Importing Data - Bokeh Charts*

# %%
def evaluate_random_data(n, evaluation, seed=543210):
    # YOUR CODE HERE
#     print("seed:", seed)
    rs = np.random.RandomState(seed)
    randList = rs.randint(0,101, n)
    randSeries = pd.Series(randList)
#     print("randList :: ", randList)
    
    result = []
    if(evaluation =='mean'):
        result = randSeries.mean()
    elif(evaluation =='median'):
        result = randSeries.median()
    elif(evaluation =='std'):
        result = randSeries.std()
#     print("result :: ", result)
    return result

    raise NotImplementedError()

# %%
# Check a RandomState object is instantiated
tmp_rs = np.random.RandomState
del np.random.RandomState

try:
    evaluate_random_data(100, 'mean')
except AttributeError:
    print('The function correctly uses RandomState')
else:
    raise AssertionError('The function does not use RandomState')
finally:
    np.random.RandomState = tmp_rs

    
assert_equal(evaluate_random_data(100, 'mean', 511419), 47.39)
assert_equal(evaluate_random_data(100, 'mean', 364235), 48.45)

assert_equal(evaluate_random_data(100, 'median', 511419), 46)
assert_equal(evaluate_random_data(100, 'median', 364235), 44)

output = evaluate_random_data(100, 'std', 511419)
"{0:.4f}".format(round(output,4))
assert_equal("{0:.4f}".format(round(output,4)), '29.2968')

output = evaluate_random_data(100, 'std', 364235)
"{0:.4f}".format(round(output,4))
assert_equal("{0:.4f}".format(round(output,4)), '30.5159')

print('All tests successfully passed')
# Out:
# The function correctly uses RandomState
# All tests successfully passed

# %% [markdown]
# ### Question 1(b) [3 marks]
#
# The function `get_data` (provided) returns a Pandas `Series` for the given collection.  Using data from this function, and the PyMongo `collection_names` function, write a function `get_means` which takes the mean `RatingValue` from the first `n` collections in the `collection_names()` function.
#
# - You should **sort** `collection_names` in ascending alphabetical order.  Note that this is a Python `list` rather than a `Cursor`, so use **[this guide to sorting lists](https://wiki.python.org/moin/HowTo/Sorting)** to help you
# - The function should **return** a **Pandas `Series` object**, with a **name** of **`RatingValueMeans`**.
# - You should use the function from Question 1(a) to get a `Series` object of the `RatingValue`, and **obtain the mean** from that object
# - N.B. Be very careful you properly exit your loop!
#
# *Hint: Week 3, Guided Exercise 4, Cursors*
# *Hint: Week 4, Guided Exercise 2, Importing Data - Bokeh Charts*

# %%
def get_data(collection):
    cursor = db[collection].find({},{'RatingValue': 1, '_id':0})
    rating_values = pd.DataFrame(list(cursor))['RatingValue']
    return rating_values

def get_means(n):
    # YOUR CODE HERE    
    # sort collection_names in ascending alphabetical order
    colNames = sorted(db.collection_names() )
#     print(colNames)
    
    # means collecting list.
    resultList = []
    for colName in colNames[ :n ]:
        # collecting of mean of sorted col name data.
        resultList.append(get_data(colName).mean())
        
    # You should use the function from Question 1(a) to get a `Series` object of the `RatingValue`
#     RatingValueMeans = evaluate_random_data(n , 'mean', seed=543210)
    # 문제-답변 의도(추측)
    RatingValueMeans = pd.Series(resultList)
    return RatingValueMeans
    
    raise NotImplementedError()

# %%
# You don't need to write anything here
means = get_means(10)

assert_equal(type(means), pd.Series)
assert_equal(len(means), 10)
assert_equal(round(means.sum(), 4), 27.2436)
means = get_means(12)
assert_equal(len(means), 12)
assert_equal(round(means.sum(), 4), 36.2604)
print('All tests passed successfully')
# Out:
# All tests passed successfully

# %% [markdown]
# ### Question 1(c) [4 marks]
#
# Create a function `get_sample_mean_distribution` which **returns** a series of the distribution of sample means of the `RatingValue` of the data from a given series.  The function should be defined as follows:
# - `data`: A `Series` object of the mean ratings of establishments
# - `n`: integer, the size of the sample
# - `m=1000`: integer, the amount of times to repeat the procedure
# - `seed=543210`: integer, default value 543210.  This should set a [`RandomState`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.RandomState.html) instance to be initialised with this value as an argument.
# - You should use the Pandas [`sample`](http://pandas.pydata.org/pandas-docs/version/0.19.2/generated/pandas.DataFrame.sample.html) function to generate your samples.
#
# The function should **return** the output as a **Pandas `Series` object**.
#
# *Hint: Week 4, Guided Exercise 2, Randomness*

# %%
# 'seed = 543210', this value is the default setting for seed
def get_sample_mean_distribution(data, n, m=1000, seed=543210):
    # YOUR CODE HERE 
#     print("n:{} // m:{} // seed:{} ".format(n, m, seed))
    
    # set sampling conditions
    size = n
    randSeed = np.random.RandomState(seed)

    # result list of sample means
    resultList = []
    for i in range(0, m):
        # n = number of size, random state = fix seed.
        sampleSeries = data.sample(n=size, random_state=randSeed)  
        sampleMean = sampleSeries.mean()
        resultList.append(sampleMean) 
#     print(resultList)
        
    # returning list to pandas series
    resultSeries = pd.Series(resultList)
    return resultSeries
    raise NotImplementedError()

# %%
# You don't need to write anything here
m = 1000
n = 20
data = pd.Series([5, 5, 5, 5, 5, 4, 5, 4, 5, 4, 5, 5, 3, 4, 4, 5, 5, 5, 4, 5, 5, 5, 5, 4, 2, 4, 5, 5, 4, 5])
seed = 123456
actual_output = get_sample_mean_distribution(data, n, m, seed)

assert_equal(len(actual_output), 1000)
assert_equal(round(actual_output.sum(),4), 4528.6)

# Check randomness is working:
# The same seed should lead to the same result
seed_test_equal = get_sample_mean_distribution(data, n, m, seed)
assert_equal(actual_output.mean(), seed_test_equal.mean())

# A different seed should not be equal
seed_test_not_equal = get_sample_mean_distribution(data, n, m, 54321)
assert_not_equal(actual_output.mean(), seed_test_not_equal.mean())

print('All tests successfully passed')
# Out:
# All tests successfully passed

# %% [markdown]
# ### Question 1(d) [2 marks]
#
# Using the output from Question 1(c), **plot a histogram** illustrating the distribution, and **return** the histogram as the output of the function `plot_sample_mean_distribution`.
#
# This function should take the same parameters as the `get_sample_mean_distribution`, so that it can call that function to obtain the data.  The histogram should have **10 bins**.
#
# *Hint: Week 1, Guided Exercise 1, Python Primer*
# *Hint: Week 2, Guided Exercise 2, Python for Data Science*
# *Hint: Week 4, Guided Exercise 2, IQR & Outliers - Bokeh Charts*
# *Hint: Week 4, Guided Exercise 3, Residual Analysis*

# %%
def plot_sample_mean_distribution(data, n, m=1000, seed=543210):
    # YOUR CODE HERE
    # use get_sample_mean_distribution
    actual_output = get_sample_mean_distribution(data, n, m, seed)
    
    hist = Histogram(actual_output, bins=10 )
    show(hist)
    return hist
    raise NotImplementedError()

# %%
# You don't need to write anything here
data = pd.Series([5, 5, 5, 5, 5, 4, 5, 4, 5, 4, 5, 5, 3, 4, 4, 5, 5, 5, 4, 5, 5, 5, 5, 4, 2, 4, 5, 5, 4, 5])

# assert_equal())
assert_equal(type(plot_sample_mean_distribution(data, 20)), Chart)
# Check Histogram
old_hist = Histogram
del Histogram

try:
    plot_sample_mean_distribution(data, 20)
except NameError:
    pass
else:
    raise AssertionError("The chart does not appear to be a Histogram")
finally:
    Histogram = old_hist
    del old_hist

print('All tests successfully passed')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2b0276a6-6307-4e31-900e-7a94f1bd1711"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("2b0276a6-6307-4e31-900e-7a94f1bd1711").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2b0276a6-6307-4e31-900e-7a94f1bd1711");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2b0276a6-6307-4e31-900e-7a94f1bd1711' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6ed770e2-d823-4083-90ea-9a0c54676d89":{"roots":{"references":[{"attributes":{},"id":"a7434ba6-2795-4c20-9d07-a772f5f076ec","type":"ToolEvents"},{"attributes":{"data_source":{"id":"4b6781cd-5f4c-4a84-a558-438ec9b7f1de","type":"ColumnDataSource"},"glyph":{"id":"179b5134-28b6-4257-bdaa-f98fe4dfc87c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cdcf8df5-2dc5-4906-adeb-a7ebe71f62f2","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"179b5134-28b6-4257-bdaa-f98fe4dfc87c","type":"Rect"},{"attributes":{"location":"top_left","plot":{"id":"42c7f773-aab9-4276-a49d-b93aee3826d9","subtype":"Chart","type":"Plot"}},"id":"62e17fb9-e5f8-489d-9b26-11c8dfbdd8f6","type":"Legend"},{"attributes":{},"id":"2536dfc6-b534-46e5-8384-14d28a61db68","type":"BasicTicker"},{"attributes":{"plot":{"id":"42c7f773-aab9-4276-a49d-b93aee3826d9","subtype":"Chart","type":"Plot"}},"id":"b1b84907-bf3d-4f88-8346-c477d0dc2ebe","type":"ResetTool"},{"attributes":{"callback":null,"end":387.20000000000005},"id":"059879cd-8aa4-42b4-9ad3-f61c711a4aab","type":"Range1d"},{"attributes":{"callback":null,"column_names":["color","width","y","line_alpha","x","label","fill_alpha","height","line_color"],"data":{"chart_index":["(4.550000, 4.600000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[352.0],"label":["(4.550000, 4.600000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.04999999999999982],"x":["4.574999999999999"],"y":[176.0]}},"id":"3b73c188-59b6-4471-b5e9-4b87f53166e5","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"cb1310db-3927-4a19-a5cd-402143f5a644","type":"ColumnDataSource"},"glyph":{"id":"c38da307-8875-4842-8947-ad9261b1a2d1","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d77aae8a-2bc8-4030-bc56-bdc35c6c00ea","type":"GlyphRenderer"},{"attributes":{},"id":"246768d6-d12c-4666-8f33-2185f4f3a12e","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["color","width","y","line_alpha","x","label","fill_alpha","height","line_color"],"data":{"chart_index":["(4.400000, 4.450000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[83.0],"label":["(4.400000, 4.450000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.05000000000000071],"x":["4.425000000000001"],"y":[41.5]}},"id":"ffe49652-f92f-4232-b0e4-b3f4ac76b671","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["color","width","y","line_alpha","x","label","fill_alpha","height","line_color"],"data":{"chart_index":["(4.500000, 4.550000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[200.0],"label":["(4.500000, 4.550000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.04999999999999982],"x":["4.525"],"y":[100.0]}},"id":"d9685b0c-7160-4669-9e3e-848be7eb8881","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3b73c188-59b6-4471-b5e9-4b87f53166e5","type":"ColumnDataSource"},"glyph":{"id":"4d86c7fd-3eee-4d76-8775-79c581ca22c4","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"20b62a92-adaf-4cde-95ee-de7ff9f5e3e0","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"42c7f773-aab9-4276-a49d-b93aee3826d9","subtype":"Chart","type":"Plot"}},"id":"7829aa64-b915-48af-b120-9abbc35883f5","type":"WheelZoomTool"},{"attributes":{},"id":"a77c9258-561b-44d0-b0d5-60aab6a92be2","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"10626178-077d-40e4-92d2-db723ba6efa6","type":"Rect"},{"attributes":{"callback":null,"column_names":["color","width","y","line_alpha","x"," ...
# All tests successfully passed

# %% [markdown]
# ## Question 2: Linear Regression
#
# This question uses a different dataset in order to illustrate linear regression.  We'll use a dataset similar to the cars dataset given as an example in the videos.
#
# ### Question 2(a) [1 mark]
#
# Create a function `get_car_data` which uses the Pandas `read_csv` to import the data in the `cars.csv` file and **return** a `DataFrame` of the data (The `cars.csv` file is in the same directory in the notebook)
#
# *Hint: Week 4, Guided Exercise 3, Classification - Importing Data*

# %%
def get_car_data():
    # YOUR CODE HERE
    # init DataFrame to return.
    df = pd.read_csv('cars.csv');
    return df
    raise NotImplementedError()

# %%
# You don't need to write anything here
assert_equal(len(get_car_data()), 1155)
assert_equal(type(get_car_data()), pd.DataFrame)
print('All tests successfully passed')
# Out:
# All tests successfully passed

# %% [markdown]
# ### Question 2(b) [3 marks]
#
# Create a **function** `remove_outliers` which removes the outliers from the dataset according to the $lower - (1.5 * IQR)$ and $upper + (1.5 * IQR)$ rule.  The function should have the following parameters:
#
# - `data` a Pandas `DataFrame`
# - `field` a string, which will say for which of the fields in the `DataFrame` to locate and remove outliers
#
# The function should **return** the `DataFrame` without the outliers.
#
# *Hint: Week 4, Guided Exercise 2, IQR*
# *Hint: Week 4, Guided Exercise 3, Residual Analysis*

# %%
def remove_outliers(data, field):
    # YOUR CODE HERE
    dataValList = data[field].values.tolist();
#     data = pd.DataFrame({field: dataValList})
    upper = float(data[field].quantile(0.75))
    lower = float(data[field].quantile(0.25))
    iqr = upper - lower
    LB = lower - (iqr * 1.5)
    UB = upper + (iqr * 1.5)
#     print('min:',min(dataValList),'//max:',max(dataValList),'//upper:',upper,'//lower:',lower,'//iqr:',iqr)
    # [[field]]: DF의 field명 지정.
    # 하지만, 아래 테스트의도는 data를 overwrite하는것으로 봐서, 
    # filter로써 모든 field가 남아잇길 바라고잇음.
    data = data[(data[field] > LB ) & (data[field] < UB )] #[[field]] - return 필드지정, 없으면 모든 field return.
    return data
    raise NotImplementedError()

# %%
# You don't have to write anything here
data = get_car_data()

data = remove_outliers(data, 'Price')
assert_equal(data.count()['Price'], 1101)

data = remove_outliers(data, 'Mileage')
assert_equal(data['Mileage'].count(), 1100)

data = remove_outliers(data, 'Year')
assert_equal(data['Year'].count(), 1092)
print('All tests successfully passed')
# Out:
# All tests successfully passed

# %% [markdown]
# ### Question 2(c) [2 marks]
# Create a function `scatter_feature`, which generates a **scatter** plot of data.  The function should take two parameters: `data`, a `DataFrame` of the regression data, and `feature_name`, the column name of the feature to be used as a predictor variable.  The following should also be applied:
# - The **response** variable is the `Price` columnn
# - The function should return a **`Chart`** instance of the scatter plot.
#
# *Hint: Week 4, Guided Exercise 2, Bokeh Charts*

# %%
def scatter_feature(data, feature_name):
    """
    This function returns a scatter plot for the particular `feature_name` v Price
    `data` should be a `DataFrame`
    `feature_name` should be a string
    """
    # YOUR CODE HERE
    # scatter plot for imported bokeh.chars 
    # https://docs.bokeh.org/en/0.12.0/docs/reference/charts.html
    
    # set title
    scatterTitle = "scatter plot - "+ feature_name + " & Price"
    
    #worked - but not joined.
    sctter_plot = Scatter(data, x=feature_name, y='Price', color='green',
                          title = scatterTitle, xlabel=feature_name, ylabel='Price')

    #output on static HTML file.
    # To display the chart in the notebook, we need to run this function, otherwise calling 'show' will not work
    output_file(scatterTitle)
    
    # Jupyter에서 show하지않아도 그래프를 보여주므로 주석처리.
#     show(sctter_plot)
    
    # return  Chart instance of the scatter plot.
    return sctter_plot
    
    raise NotImplementedError()
    
show(scatter_feature(data, 'Mileage'))
show(scatter_feature(data, 'Year'))
# Out:
# INFO:bokeh.core.state:Session output file 'scatter plot - Mileage & Price' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f2cc5abc-0f44-4063-acb4-5716a95fe9ec"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f2cc5abc-0f44-4063-acb4-5716a95fe9ec").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f2cc5abc-0f44-4063-acb4-5716a95fe9ec");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f2cc5abc-0f44-4063-acb4-5716a95fe9ec' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"526fb8ef-3479-48d5-839d-50b01a557b1a":{"roots":{"references":[{"attributes":{"data_source":{"id":"05cc4560-ef07-4215-aed0-0d87819bbd3b","type":"ColumnDataSource"},"glyph":{"id":"355dac78-db63-437b-b2e7-c3546726dff3","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"029ff9a2-ce4e-4224-abb8-be8b39458241","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":187500.0,"start":-16500.0},"id":"8ed29451-92fa-477f-ae7b-24a4dedbeb7f","type":"Range1d"},{"attributes":{"plot":{"id":"6f55ade7-a4c7-487a-b916-03951154951a","subtype":"Chart","type":"Plot"}},"id":"291709b8-6eba-4788-a922-4bc2a4ae3dcd","type":"HelpTool"},{"attributes":{"overlay":{"id":"147387d6-5369-4563-9fd2-b6183658e2d1","type":"BoxAnnotation"},"plot":{"id":"6f55ade7-a4c7-487a-b916-03951154951a","subtype":"Chart","type":"Plot"}},"id":"f42a6c19-110c-4059-b86f-f5d7a07fb112","type":"BoxZoomTool"},{"attributes":{"location":"top_left","plot":{"id":"6f55ade7-a4c7-487a-b916-03951154951a","subtype":"Chart","type":"Plot"}},"id":"c3db28fa-f26a-45c3-96ff-44f529aeb1d8","type":"Legend"},{"attributes":{"plot":{"id":"6f55ade7-a4c7-487a-b916-03951154951a","subtype":"Chart","type":"Plot"}},"id":"a863b77d-4744-45ab-9761-8cdf8ac2ef51","type":"ResetTool"},{"attributes":{"plot":{"id":"6f55ade7-a4c7-487a-b916-03951154951a","subtype":"Chart","type":"Plot"}},"id":"2dd58611-40d9-46c7-89a2-da83008e5db8","type":"PanTool"},{"attributes":{"axis_label":"Price","formatter":{"id":"96d1cab7-a331-46e9-826b-d82dee346110","type":"BasicTickFormatter"},"plot":{"id":"6f55ade7-a4c7-487a-b916-03951154951a","subtype":"Chart","type":"Plot"},"ticker":{"id":"b755ec59-5ad8-45dc-ac05-e700d8eb6a37","type":"BasicTicker"}},"id":"4f110108-17e2-4f04-bd86-beb6292cad3e","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null, ...
# INFO:bokeh.core.state:Session output file 'scatter plot - Year & Price' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3c4f3cf8-200f-4eb5-99de-36fa039281aa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("3c4f3cf8-200f-4eb5-99de-36fa039281aa").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3c4f3cf8-200f-4eb5-99de-36fa039281aa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3c4f3cf8-200f-4eb5-99de-36fa039281aa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ca4734bb-b58c-48ba-ac99-a63fdb383158":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a1005295-9de7-4710-ba88-9f69e90ae7a7","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"adce8120-9909-4968-ad6e-8e6f264adbfa","subtype":"Chart","type":"Plot"},"ticker":{"id":"6cf61532-d6e7-404a-b3bb-6b7085481baf","type":"BasicTicker"}},"id":"6afe2c17-3767-4148-a237-f7209ea8e30b","type":"Grid"},{"attributes":{"plot":{"id":"adce8120-9909-4968-ad6e-8e6f264adbfa","subtype":"Chart","type":"Plot"}},"id":"ac157194-3dc4-4323-b290-0455a5b32ed0","type":"WheelZoomTool"},{"attributes":{},"id":"6cf61532-d6e7-404a-b3bb-6b7085481baf","type":"BasicTicker"},{"attributes":{"plot":{"id":"adce8120-9909-4968-ad6e-8e6f264adbfa","subtype":"Chart","type":"Plot"}},"id":"cb3fc6ee-0fab-4521-82a4-3f348aec1174","type":"HelpTool"},{"attributes":{"location":"top_left","plot":{"id":"adce8120-9909-4968-ad6e-8e6f264adbfa","subtype":"Chart","type":"Plot"}},"id":"e192820b-6bd7-416a-b737-c825f77d3310","type":"Legend"},{"attributes":{"overlay":{"id":"a1005295-9de7-4710-ba88-9f69e90ae7a7","type":"BoxAnnotation"},"plot":{"id":"adce8120-9909-4968-ad6e-8e6f264adbfa","subtype":"Chart","type":"Plot"}},"id":"a3a525db-ab6c-4b50-859d-2eb5c0ef86ec","type":"BoxZoomTool"},{"attributes":{"callback":null,"end":2017.5,"start":1999.5},"id":"4e2f1e68-69db-4f71-ad59-42e87453d041","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"green"},"line_color":{"value":"green"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"7bfaeb8d-140c-4f67-b661-02817d1be09d","type":"Circle"},{"attributes":{"axis_label":"Year","formatter":{"id":"16cfc894-b834-4d72-818c-93192ac80a1d","type":"BasicTickFormatter"},"plot":{"id":"adce8120-9909-4968-ad6e-8e6f264adbfa","subtype":"Chart","type":"Plot"},"ticker":{"id":"d6a47731-4ad5-4fc7-a89e-a9bb37d9568b","type":"BasicTicker"}},"id":"3f9e8f9c-73f5-422f-8982-7991200824fd","type":"LinearAxis"},{"attributes":{},"id":"d6a47731-4ad5-4fc7-a89e-a9bb37d9568b","type":"BasicTicker"},{"attributes":{"axis_label":"Price","formatter":{"id":"01e2e56c-3251-464f-ad10-c350ba8148dc","type":"BasicTickFormatter"},"plot":{"id":"adce8120-9909-4968-ad6e-8e6f264adbfa","subtype":"Chart","type":"Plot"},"ticker":{"id":"6cf61532-d6e7-404a-b3bb-6b7085481baf","type":"BasicTicker"}},"id":"dfda80ad-8aae-4ee0-b3e2-6cb4aa138149","type":"LinearAxis"},{"attributes":{"plot":{"id":"adce8120-9909-4968-ad6e-8e6f264adbfa","subtype":"Chart","type":"Plot"}},"id":"9c82f10f-b7c0-4c97-9bc0-e39b643769bc","type":"ResetTool"},{"attributes":{"callback":null,"end":13642.1,"start":-123.10000000000014},"id":"714b7b32-4257-451b-ba55-39d33c99ae17","type":"Range1d"},{"attributes":{"plot":{"id":"adce8120-9909-4968-ad6e-8e6f264adbfa","subtype":"Chart","type":"Plot"},"ticker":{"id":"d6a47731-4ad5-4fc7-a89e-a9bb37d9568b","type":"BasicTicker"}},"id":"d63dcd25-cc4d-4293-a91a-25f8adaaee77","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"294d3d26-539e-4ce5-8a0a-682121c8c98a","type":"PanTool"},{"id":"ac157194-3dc4-4323-b290-0455a5b32ed0","type":"WheelZoomTool"},{"id":"a3a525db-ab6c-4b50-859d-2eb5c0ef86ec","type":"BoxZoomTool"},{"id":"4cc86b97-f337-4251-98d9-9600cc5baad6","type":"SaveTool"},{"id":"9c82f10f-b7c0-4c97-9bc0-e39b643769bc","type":"ResetTool"},{"id":"cb3fc6ee-0fab-4521-82a4-3f348aec1174","type":"HelpTool"}]},"id":"985b479c-9ef5-42f9-af70-8f3063413bea","type":"Toolbar"},{"attributes":{"below":[{"id":"3f9e8f9c-73f5-422f-8982-7991200824fd","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"dfda80ad-8aae-4ee0-b3e2-6cb4aa138149","type":"LinearAxis"}],"rend ...

# %% [markdown]
# ### Question 2(d) [3 marks]
#
# Using the `scikit-learn` libarary, write a function `split_data` which generates a **training** and a **test** dataset, based on features passed in as arguments.  The function should have three parameters:
#
# - **`data`** a `DataFrame` containing the data to be evaluated
# - **`features`** a list of strings which will be used to select the features from the dataset
# - **`seed`** an integer with default value `543210`, which  should be used to initialise a `RandomState` (as with Question 1(a),
# - The function should return the output of **[`train_test_split`](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)**, using that `RandomState`, and data with the selected features from the `features` parameter.
# - The **test size** of the returned data should be **20%**
# - As with question 2c the **response** variable shuld be the **'Price'** columnn
#
# *Hint: Week 4, Guided Exercise 3, Training and Testing Data*

# %%
def split_data(data, features, seed=543210):
    # YOUR CODE HERE
#     print(data)
    #response variable - Price.
#     responseDataList = data['Price'].values.tolist()
    responseDataList = np.asarray(data['Price'])

    randSeed = np.random.RandomState(seed)
    return train_test_split( data[features], responseDataList, test_size=0.2, random_state=randSeed)
    
    raise NotImplementedError()

# %%
# You don't need to write anything here
data = get_car_data()

x1, x2, y1, y2 = split_data(data, ['Mileage'])
assert_equal(len(x1), 924)
assert_equal(len(x2), 231)

assert_equal(x1.index[0], 607)
x1, x2, y1, y2 = split_data(data, ['Mileage'], 123456)
assert_equal(x1.index[0], 642)
print("All tests successfully passed")
# Out:
# All tests successfully passed

# %% [markdown]
# ### Question 2(e) [4 marks]
#
# Create a function `evaluate_model` to **fit** and **evaluate** the linear regression model using the test the accuracy of the model with different features using $R^2$.  The function should contain the same parameters as `split_data`, so it can call that function.
#
# The model should be evaluated based on the test data.
#
# *Hint: Week 2, Guided Exercise 2, Exercise 3a*
# *Hint: Week 4, Guided Exercise 3, Lineaar Regression - Fitting The Model - Residual Analysis*

# %%
def evaluate_model(data, features, seed=543210):
    # YOUR CODE HERE
    # X: predictor var, y: ass. response var
#     print('seed::', seed, ' // features::', features)
    # fit - linear model.
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    X_train, X_test, y_train, y_test = split_data(data, features, seed)

    # Call the fit function on the data
    lm = LinearRegression()
    lm.fit(X_test, y_test)
#         print(vars(lm))
        ## {'normalize': False, 'intercept_': 10417.290416744017, 'rank_': 1, 'coef_': array([-0.06574963]), 'fit_intercept': True, '_residues': 7864086506.4485512, 'n_jobs': 1, 'singular_': array([ 1109202.20149868]), 'copy_X': True}

    # lm : y = mx + c
    m = lm.coef_[0]
    c = lm.intercept_
    print('y = %fx + %f' % (m,c)) 
        ## y = -0.065750x + 10417.290417
    lm.predict(np.asarray(X_test))
        ## [ 10417.09316784  10416.96166857  10417.02741821]

#     print('test :: ', lm.score(X_test, y_test))
    
#     np.asarray(data['Price'])
    
    # Evaluate and return the lm test score
    return lm.score(X_test, y_test)
    
    raise NotImplementedError()

# %%
## You don't need to write anything here

data = get_car_data()

assert_equal(round(evaluate_model(data, ['Mileage'], 511419), 4),0.4742)
assert_equal(round(evaluate_model(data, ['Year'], 511419), 4), 0.2526)
assert_equal(round(evaluate_model(data, ['Year', 'Mileage'], 511419), 4), 0.4754)
print("All tests successfully passed")
# Out:
# y = -0.066003x + 10429.102482
# y = 398.925568x + -794781.187570
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-481-14626e37ea30> in <module>()
#       4
#       5 assert_equal(round(evaluate_model(data, ['Mileage'], 511419), 4),0.4742)
# ----> 6 assert_equal(round(evaluate_model(data, ['Year'], 511419), 4), 0.2526)
#       7 assert_equal(round(evaluate_model(data, ['Year', 'Mileage'], 511419), 4), 0.4754)
#       8 print("All tests successfully passed")
#
# /opt/conda/lib/python3.5/unittest/case.py in assertEqual(self, first, second, msg)
#     818         """
#     819         assertion_func = self._getAssertEqualityFunc(first, second)
# --> 820         assertion_func(first, second, msg=msg)
#     821
#     822     def assertNotEqual(self, first, second, msg=None):
#
# /opt/conda/lib/python3.5/unittest/case.py in _baseAssertEqual(self, first, second, msg)
#     811             standardMsg = '%s != %s' % _common_shorten_repr(first, second)
#     812             msg = self._formatMessage(msg, standardMsg)
# --> 813             raise self.failureException(msg)
#     814
#     815     def assertEqual(self, first, second, msg=None):
#
# AssertionError: 0.39500000000000002 != 0.2526
