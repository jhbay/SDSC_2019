# %% [markdown]
# # Statistics Guided Exercise
#
# For using statistics with Python, we will be looking at the Pandas library.  Pandas itself is build on top of another library, NumPy, and both have their own data structures.  In this exercise, we will go over these data structures, and introduce you to Bokeh, which is a visualisation library you will be using in this exercise and the next for graphs and charts.

# %% [markdown]
# ## Pandas
#
# Pandas is a Python library for data analysis in Python.  It providies some useful functions and data structures for the collection and analysis of data.  In particular, we will be making use of the **`DataFrame`** and **`Series`** classes.
#
# A `DataFrame` object represents data in a series of rows (individual observations of data) and columns (features or variables) within those data.  Each of those rows and columns can be extracted, and they then become a `Series`.  We will work through an example to illustrate these concepts.
#
# ### Importing Data
#
# There are convenience functions to import data, such as [**`read_json`**](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_json.html) and [**`read_csv`**](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) which, as their names suggest, will import data which is already in a particular format.  For this example, we will import data from the MongoDB database we used in the exercise last week.
#
# For this example, we will import the first 1000 documents (*MongoDB stores data records as BSON documents. BSON is a binary representation of JSON documents, though it contains more data types than JSON*), in the UK collection into a Pandas `DataFrame`.  Run the cell below

# %%
# Convention is to import numpy and pandas with abbreviated names
# This means that instead of using pandas.read_csv, you would use pd.read_csv
import numpy as np
import pandas as pd

from bokeh.io import output_notebook, show
from bokeh.charts import *

# Import PyMongo, so that we can query some data
# 'mongodb://cpduser:M13pV5woDW@mongodb/health_data' is the location of the data we will be using

from pymongo import MongoClient
client = MongoClient('mongodb://cpduser:M13pV5woDW@mongodb/health_data')
db = client.health_data

cursor = db.uk.find({}).limit(1000)

# Unfortunately, Pandas does not support PyMongo objects for import, so we need to cast it to a list
listy = list(cursor)

# Create a Pandas DataFrame with the list object as a parameter
first_1000 = pd.DataFrame(listy)

# %% [markdown]
# Now we have our imported data in a **`DataFrame`** object.  Like any other Python object, it has a collection of attributes and methods which we can use.  We will go over some here, but see [the documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html) for a full list.  We'll start by seeing what the data looks like by calling the `head()` function on the data:

# %%
# Filtering the data in the DataFrame to only return rows where RatingValue < 3
first_1000[first_1000['RatingValue'] < 3]
# Out:
#                          AddressLine1              AddressLine2 AddressLine3  \
# 3                                 NaN       30-34 Holmrook Road      Preston
# 19                                NaN            53A Fylde Road      Preston
# 64                                NaN         130 Church Street      Preston
# 85                                NaN     158-162 New Hall Lane      Preston
# 108                               NaN     161-163 St Pauls Road      Preston
# 120                               NaN          21 Harewood Road      Preston
# 127                               NaN             69 Fylde Road      Preston
# 180                               NaN          198c Miller Road      Preston
# 189                               NaN        91 Fishergate Hill      Preston
# 206                               NaN         169 St Pauls Road      Preston
# 230                               NaN        214 Ribbleton Lane      Preston
# 265                               NaN             57 Marsh Lane      Preston
# 272                               NaN          69 Meadow Street      Preston
# 273                               NaN        434 Blackpool Road      Preston
# 276                               NaN        16b Adelphi Street      Preston
# 292                               NaN         49 Blackpool Road      Preston
# 327                               NaN           33-35 Moor Lane      Preston
# 350                               NaN        393 Blackpool Road      Preston
# 398                               NaN          25 New Hall Lane      Preston
# 426                               NaN         198 New Hall Lane      Preston
# 432                               NaN         194 Fletcher Road      Preston
# 459                               NaN           29 Market Place      Preston
# 469                               NaN     230-232 New Hall Lane      Preston
# 474                               NaN            68 Watery Lane      Preston
# 518                               NaN         284 New Hall Lane      Preston
# 561                  1b Aqueduct Mill       222 Aqueduct Street      Preston
# 575                               NaN        954 Blackpool Road      Preston
# 632                               NaN        241 Ribbleton Lane      Preston
# 648                               NaN       50 Greenbank Street      Preston
# 654                               NaN           154 Miller Road      Preston
# 663                 Fishergate Centre                Fishergate      Preston
# 665                               NaN       60 Plungington Road      Preston
# 687                               NaN          27 Church Street      Preston
# 700                               NaN       138 Manchester Road      Preston
# 704                               NaN         169 New Hall Lane      Preston
# 719                               NaN             140 Friargate      Preston
# 752                               NaN      119 Ribbleton Avenue      Preston
# 787                               NaN                Eaves Lane      Preston
# 821                               NaN    42-46 Holme Slack Lane      Preston
# 827   Unit B1b Deepdale Shopping Park            Blackpool Road      Preston
# 828                               NaN              281 Tag Lane      Preston
# 829                               NaN  15-17 Corporation Street      Preston
# 856                               NaN         454 New Hall Lane      Preston
# 863                               NaN      4-6 Ribbleton Avenue      Preston
# 868  Farringdon Park Community Centre      18-24 Thirlmere Road      Preston
# 871                               NaN         7 Manchester Road      Preston
# 896                               NaN         172 Deepdale Road      Preston
# 912                               NaN              18 East View      Preston
# 925                               NaN     323-325 Garstang Road      Preston
# 936                               NaN           36 Market Place      Preston
# 954                               NaN         171 New Hall Lane      Preston
#
#     AddressLine4                            BusinessName  \
# 3            NaN                               A L Salam
# 19           NaN                            Ale Emporium
# 64           NaN                   Ayaan's Miami Chicken
# 85           NaN  Bargain Booze Select Convenience Store
# 108          NaN                    Bismillah Food Store
# 120          NaN                Bolton Halal Meat Market
# 127          NaN                          Booze Brothers
# 180          NaN                          Carlitos Pizza
# 189          NaN                        Charlies Sarnies
# 206          NaN                       Choma Grill House
# 230          NaN                               Corleones
# 265          NaN                 Deanos Eastern Flavours
# 272          NaN                                Deli Bar
# 273          NaN                  Deli with a Difference
# 276          NaN                       Delicious Delight
# 292          NaN                               Don Mario
# 327          NaN             Far East Oriental Foodstore
# 350          NaN                      Fredy's at Eatwell
# 398          NaN                       Gourmet and Grill
# 426          NaN                       Gujrat Food Store
# 432          NaN                             Happy House
# 459          NaN                           Home Bargains
# 469          NaN           Hussains Spice & Fruit Centre
# 474          NaN                      Ignite Shisha Cafe
# 518          NaN                             K2 Chippery
# 561          NaN                     Laser Quest Preston
# 575          NaN                               Lea Store
# 632          NaN                       Mash's Wing Ranch
# 648          NaN                        MFA Bowl Limited
# 654          NaN                        Miller Road Cafe
# 663          NaN                          Moka Cafes Ltd
# 665          NaN                       Moms Sandwich Bar
# 687          NaN                                 Mr Joes
# 700          NaN                        Naafiah Takeaway
# 704          NaN                         Nasza Biedronka
# 719          NaN                            News Express
# 752          NaN                          One Stop Store
# 787          NaN                         Plough at Eaves
# 821          NaN                               Pound Box
# 827          NaN                   Poundworld Retail Ltd
# 828          NaN                          PR2 Bakery Ltd
# 829          NaN                                 Premier
# 856          NaN                             Price Check
# 863          NaN                              Quick Shop
# 868          NaN                                    RAFT
# 871          NaN                           Raja Original
# 896          NaN                                  Romero
# 912          NaN                         Royal Piri Piri
# 925          NaN                              Sai Surbhi
# 936          NaN                             Scrumptious
# 954          NaN                               Shop Rite
#
#                               BusinessType BusinessTypeID  \
# 3                        Retailers - other           4613
# 19                       Pub/bar/nightclub           7843
# 64                  Takeaway/sandwich shop           7844
# 85                       Retailers - other           4613
# 108                      Retailers - other           4613
# 120                      Retailers - other           4613
# 127                      Retailers - other           4613
# 180                 Takeaway/sandwich shop           7844
# 189                 Takeaway/sandwich shop           7844
# 206                 Takeaway/sandwich shop           7844
# 230                 Takeaway/sandwich shop           7844
# 265                 Takeaway/sandwich shop           7844
# 272                 Takeaway/sandwich shop           7844
# 273                Restaurant/Cafe/Canteen              1
# 276                 Takeaway/sandwich shop           7844
# 292                 Takeaway/sandwich shop           7844
# 327                      Retailers - other           4613
# 350                 Takeaway/sandwich shop           7844
# 398                 Takeaway/sandwich shop           7844
# 426                      Retailers - other           4613
# 432                 Takeaway/sandwich shop           7844
# 459                      Retailers - other           4613
# 469                      Retailers - other           4613
# 474                Restaurant/Cafe/Canteen              1
# 518                 Takeaway/sandwich shop           7844
# 561                Other catering premises           7841
# 575                      Retailers - other           4613
# 632                 Takeaway/sandwich shop           7844
# 648                Restaurant/Cafe/Canteen              1
# 654                Restaurant/Cafe/Canteen              1
# 663                Restaurant/Cafe/Canteen              1
# 665                 Takeaway/sandwich shop           7844
# 687                 Takeaway/sandwich shop           7844
# 700                 Takeaway/sandwich shop           7844
# 704                      Retailers - other           4613
# 719                      Retailers - other           4613
# 752  Retailers - supermarkets/hypermarkets           7840
# 787                      Pub/bar/nightclub           7843
# 821  Retailers - supermarkets/hypermarkets           7840
# 827                      Retailers - other           4613
# 828                      Retailers - other           4613
# 829                      Retailers - other           4613
# 856                      Retailers - other           4613
# 863                      Retailers - other           4613
# 868                Other catering premises           7841
# 871                 Takeaway/sandwich shop           7844
# 896                 Takeaway/sandwich shop           7844
# 912                Restaurant/Cafe/Canteen              1
# 925                Restaurant/Cafe/Canteen              1
# 936                Restaurant/Cafe/Canteen              1
# 954                      Retailers - other           4613
#
#      ConfidenceInManagement  FHRSID  \
# 3                      10.0  135423
# 19                     20.0  479641
# 64                     20.0  335295
# 85                     10.0  448032
# 108                    10.0  454884
# 120                    20.0   51647
# 127                    10.0  448082
# 180                    10.0  369063
# 189                    20.0   69893
# 206                    20.0   86973
# 230                    10.0  637915
# 265                    20.0  335352
# 272                    10.0  121600
# 273                     5.0  133196
# 276                    10.0  335380
# 292                    10.0  335301
# 327                    10.0  479591
# 350                    20.0  201373
# 398                    20.0  629593
# 426                    10.0  479519
# 432                    10.0  115804
# 459                    10.0  479764
# 469                    20.0  479921
# 474                    20.0  768229
# 518                    10.0  137209
# 561                    10.0  850075
# 575                    10.0  479767
# 632                    20.0  201370
# 648                    10.0  448112
# 654                    10.0   70877
# 663                    10.0   97856
# 665                    20.0  708327
# 687                    10.0  335282
# 700                    20.0  335364
# 704                    20.0  726619
# 719                    10.0  479766
# 752                    10.0  121893
# 787                    10.0   92213
# 821                    20.0  136094
# 827                    10.0  670391
# 828                    20.0   78740
# 829                    10.0  510354
# 856                    10.0  479530
# 863                    20.0  479853
# 868                    10.0  479778
# 871                    10.0  108298
# 896                    10.0  136644
# 912                    10.0   83211
# 925                    20.0  335327
# 936                    20.0   94388
# 954                    10.0  479819
#
#                                                Geocode  \
# 3    {'type': 'Point', 'coordinates': [-2.689741, 5...
# 19   {'type': 'Point', 'coordinates': [-2.7099, 53....
# 64   {'type': 'Point', 'coordinates': [-2.694741, 5...
# 85   {'type': 'Point', 'coordinates': [-2.677979, 5...
# 108  {'type': 'Point', 'coordinates': [-2.696542, 5...
# 120  {'type': 'Point', 'coordinates': [-2.686212, 5...
# 127  {'type': 'Point', 'coordinates': [-2.7099, 53....
# 180  {'type': 'Point', 'coordinates': [-2.657126, 5...
# 189  {'type': 'Point', 'coordinates': [-2.71106, 53...
# 206  {'type': 'Point', 'coordinates': [-2.696542, 5...
# 230  {'type': 'Point', 'coordinates': [-2.681277, 5...
# 265  {'type': 'Point', 'coordinates': [-2.707097, 5...
# 272  {'type': 'Point', 'coordinates': [-2.693736, 5...
# 273  {'type': 'Point', 'coordinates': [-2.727366, 5...
# 276  {'type': 'Point', 'coordinates': [-2.706293, 5...
# 292  {'type': 'Point', 'coordinates': [-2.670732, 5...
# 327  {'type': 'Point', 'coordinates': [-2.705493, 5...
# 350  {'type': 'Point', 'coordinates': [-2.72621, 53...
# 398  {'type': 'Point', 'coordinates': [-2.686259, 5...
# 426  {'type': 'Point', 'coordinates': [-2.675924, 5...
# 432  {'type': 'Point', 'coordinates': [-2.680624, 5...
# 459  {'type': 'Point', 'coordinates': [-2.699791, 5...
# 469  {'type': 'Point', 'coordinates': [-2.674142, 5...
# 474  {'type': 'Point', 'coordinates': [-2.727952, 5...
# 518  {'type': 'Point', 'coordinates': [-2.670777, 5...
# 561  {'type': 'Point', 'coordinates': [-2.715449, 5...
# 575  {'type': 'Point', 'coordinates': [-2.769314, 5...
# 632  {'type': 'Point', 'coordinates': [-2.680123, 5...
# 648  {'type': 'Point', 'coordinates': [-2.71225, 53...
# 654  {'type': 'Point', 'coordinates': [-2.670479, 5...
# 663  {'type': 'Point', 'coordinates': [-2.705764, 5...
# 665  {'type': 'Point', 'coordinates': [-2.710864, 5...
# 687  {'type': 'Point', 'coordinates': [-2.696262, 5...
# 700  {'type': 'Point', 'coordinates': [-2.693365, 5...
# 704  {'type': 'Point', 'coordinates': [-2.677047, 5...
# 719  {'type': 'Point', 'coordinates': [-2.704347, 5...
# 752  {'type': 'Point', 'coordinates': [-2.668383, 5...
# 787  {'type': 'Point', 'coordinates': [-2.770347, 5...
# 821  {'type': 'Point', 'coordinates': [-2.682601, 5...
# 827  {'type': 'Point', 'coordinates': [-2.676764, 5...
# 828  {'type': 'Point', 'coordinates': [-2.743272, 5...
# 829  {'type': 'Point', 'coordinates': [-2.70599, 53...
# 856  {'type': 'Point', 'coordinates': [-2.664235, 5...
# 863  {'type': 'Point', 'coordinates': [-2.674923, 5...
# 868  {'type': 'Point', 'coordinates': [-2.654603, 5...
# 871  {'type': 'Point', 'coordinates': [-2.693365, 5...
# 896  {'type': 'Point', 'coordinates': [-2.691229, 5...
# 912  {'type': 'Point', 'coordinates': [-2.691876, 5...
# 925  {'type': 'Point', 'coordinates': [-2.714194, 5...
# 936  {'type': 'Point', 'coordinates': [-2.699791, 5...
# 954  {'type': 'Point', 'coordinates': [-2.677047, 5...
#
#                ...             PostCode  RatingDate     RatingKey RatingValue  \
# 3              ...              PR1 6SR  2014-09-23  fhrs_2_en-GB         2.0
# 19             ...              PR1 2XQ  2015-03-18  fhrs_1_en-GB         1.0
# 64             ...              PR1 3BT  2016-02-11  fhrs_1_en-GB         1.0
# 85             ...              PR1 4DX  2014-11-26  fhrs_2_en-GB         2.0
# 108            ...              PR1 1PX  2015-10-23  fhrs_2_en-GB         2.0
# 120            ...              PR1 6XH  2016-06-08  fhrs_1_en-GB         1.0
# 127            ...              PR1 2XQ  2015-07-01  fhrs_2_en-GB         2.0
# 180            ...              PR2 6NH  2016-06-28  fhrs_2_en-GB         2.0
# 189            ...              PR1 8JD  2016-05-24  fhrs_0_en-GB         0.0
# 206            ...              PR1 1PX  2016-03-16  fhrs_1_en-GB         1.0
# 230            ...              PR1 5LD  2016-01-27  fhrs_2_en-GB         2.0
# 265            ...              PR1 8RQ  2016-07-21  fhrs_1_en-GB         1.0
# 272            ...              PR1 1TS  2016-07-28  fhrs_2_en-GB         2.0
# 273            ...              PR2 2DX  2016-06-09  fhrs_2_en-GB         2.0
# 276            ...              PR1 7BE  2015-07-30  fhrs_2_en-GB         2.0
# 292            ...              PR2 6BU  2015-12-14  fhrs_2_en-GB         2.0
# 327            ...              PR1 7AT  2015-10-28  fhrs_2_en-GB         2.0
# 350            ...              PR2 2DU  2016-03-08  fhrs_1_en-GB         1.0
# 398            ...              PR1 5NU  2015-11-03  fhrs_1_en-GB         1.0
# 426            ...              PR1 4SS  2015-06-02  fhrs_2_en-GB         2.0
# 432            ...              PR1 5HH  2016-08-09  fhrs_2_en-GB         2.0
# 459            ...              PR1 2AR  2014-10-17  fhrs_2_en-GB         2.0
# 469            ...              PR1 4ST  2015-12-17  fhrs_1_en-GB         1.0
# 474            ...              PR2 1AU  2015-04-29  fhrs_1_en-GB         1.0
# 518            ...              PR1 4SU  2016-08-12  fhrs_2_en-GB         2.0
# 561            ...              PR1 7JN  2016-03-07  fhrs_2_en-GB         2.0
# 575            ...              PR2 1XN  2014-11-28  fhrs_2_en-GB         2.0
# 632            ...              PR1 5EA  2015-11-23  fhrs_1_en-GB         1.0
# 648            ...              PR1 7JS  2016-01-28  fhrs_2_en-GB         2.0
# 654            ...              PR1 5QS  2016-06-24  fhrs_2_en-GB         2.0
# 663            ...              PR1 8HJ  2016-07-05  fhrs_2_en-GB         2.0
# 665            ...              PR1 7RA  2016-07-07  fhrs_1_en-GB         1.0
# 687            ...              PR1 3BQ  2016-01-30  fhrs_2_en-GB         2.0
# 700            ...              PR1 3YH  2016-03-08  fhrs_1_en-GB         1.0
# 704            ...              PR1 5XA  2016-04-19  fhrs_1_en-GB         1.0
# 719            ...              PR1 2EE  2016-02-19  fhrs_2_en-GB         2.0
# 752            ...              PR2 6YS  2014-12-01  fhrs_1_en-GB         1.0
# 787            ...              PR4 0BJ  2016-04-18  fhrs_2_en-GB         2.0
# 821            ...              PR1 6EY  2016-01-14  fhrs_1_en-GB         1.0
# 827            ...              PR1 6QY  2015-10-08  fhrs_2_en-GB         2.0
# 828            ...              PR2 3XA  2016-02-03  fhrs_1_en-GB         1.0
# 829            ...              PR1 2UP  2015-05-06  fhrs_2_en-GB         2.0
# 856            ...              PR1 4TA  2014-10-27  fhrs_2_en-GB         2.0
# 863            ...              PR1 5RY  2016-04-25  fhrs_1_en-GB         1.0
# 868            ...              PR1 5TR  2015-06-24  fhrs_2_en-GB         2.0
# 871            ...              PR1 3YH  2016-03-07  fhrs_2_en-GB         2.0
# 896            ...              PR1 6QA  2016-07-14  fhrs_2_en-GB         2.0
# 912            ...              PR1 5AS  2015-07-14  fhrs_2_en-GB         2.0
# 925            ...              PR2 9UP  2016-06-15  fhrs_1_en-GB         1.0
# 936            ...              PR1 2AR  2015-08-20  fhrs_1_en-GB         1.0
# 954            ...              PR1 5XA  2015-04-14  fhrs_2_en-GB         2.0
#
#          Region                                       RightToReply SchemeType  \
# 3    north_west                                                NaN       FHRS
# 19   north_west                                                NaN       FHRS
# 64   north_west                                                NaN       FHRS
# 85   north_west                                                NaN       FHRS
# 108  north_west                                                NaN       FHRS
# 120  north_west                                                NaN       FHRS
# 127  north_west                                                NaN       FHRS
# 180  north_west                                                NaN       FHRS
# 189  north_west                                                NaN       FHRS
# 206  north_west                                                NaN       FHRS
# 230  north_west                                                NaN       FHRS
# 265  north_west                                                NaN       FHRS
# 272  north_west                                                NaN       FHRS
# 273  north_west                                                NaN       FHRS
# 276  north_west                                                NaN       FHRS
# 292  north_west                                                NaN       FHRS
# 327  north_west                                                NaN       FHRS
# 350  north_west                                                NaN       FHRS
# 398  north_west                                                NaN       FHRS
# 426  north_west                                                NaN       FHRS
# 432  north_west  &lt;p&gt;\n\tWe have improved hygiene standard...       FHRS
# 459  north_west                                                NaN       FHRS
# 469  north_west                                                NaN       FHRS
# 474  north_west                                                NaN       FHRS
# 518  north_west                                                NaN       FHRS
# 561  north_west                                                NaN       FHRS
# 575  north_west                                                NaN       FHRS
# 632  north_west                                                NaN       FHRS
# 648  north_west                                                NaN       FHRS
# 654  north_west                                                NaN       FHRS
# 663  north_west                                                NaN       FHRS
# 665  north_west                                                NaN       FHRS
# 687  north_west                                                NaN       FHRS
# 700  north_west                                                NaN       FHRS
# 704  north_west                                                NaN       FHRS
# 719  north_west                                                NaN       FHRS
# 752  north_west                                                NaN       FHRS
# 787  north_west                                                NaN       FHRS
# 821  north_west                                                NaN       FHRS
# 827  north_west                                                NaN       FHRS
# 828  north_west                                                NaN       FHRS
# 829  north_west                                                NaN       FHRS
# 856  north_west                                                NaN       FHRS
# 863  north_west                                                NaN       FHRS
# 868  north_west                                                NaN       FHRS
# 871  north_west                                                NaN       FHRS
# 896  north_west                                                NaN       FHRS
# 912  north_west                                                NaN       FHRS
# 925  north_west                                                NaN       FHRS
# 936  north_west                                                NaN       FHRS
# 954  north_west                                                NaN       FHRS
#
#                                                 Scores Structural  \
# 3    {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 19   {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...        0.0
# 64   {'Hygiene': 10, 'Structural': 10, 'ConfidenceI...       10.0
# 85   {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 108  {'Hygiene': 15, 'Structural': 10, 'ConfidenceI...       10.0
# 120  {'Hygiene': 10, 'Structural': 10, 'ConfidenceI...       10.0
# 127  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 180  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 189  {'Hygiene': 15, 'Structural': 20, 'ConfidenceI...       20.0
# 206  {'Hygiene': 15, 'Structural': 15, 'ConfidenceI...       15.0
# 230  {'Hygiene': 15, 'Structural': 5, 'ConfidenceIn...        5.0
# 265  {'Hygiene': 15, 'Structural': 10, 'ConfidenceI...       10.0
# 272  {'Hygiene': 5, 'Structural': 15, 'ConfidenceIn...       15.0
# 273  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 276  {'Hygiene': 5, 'Structural': 15, 'ConfidenceIn...       15.0
# 292  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 327  {'Hygiene': 15, 'Structural': 5, 'ConfidenceIn...        5.0
# 350  {'Hygiene': 15, 'Structural': 15, 'ConfidenceI...       15.0
# 398  {'Hygiene': 15, 'Structural': 15, 'ConfidenceI...       15.0
# 426  {'Hygiene': 5, 'Structural': 15, 'ConfidenceIn...       15.0
# 432  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 459  {'Hygiene': 0, 'Structural': 15, 'ConfidenceIn...       15.0
# 469  {'Hygiene': 10, 'Structural': 10, 'ConfidenceI...       10.0
# 474  {'Hygiene': 10, 'Structural': 10, 'ConfidenceI...       10.0
# 518  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 561  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 575  {'Hygiene': 15, 'Structural': 10, 'ConfidenceI...       10.0
# 632  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 648  {'Hygiene': 15, 'Structural': 15, 'ConfidenceI...       15.0
# 654  {'Hygiene': 15, 'Structural': 10, 'ConfidenceI...       10.0
# 663  {'Hygiene': 5, 'Structural': 15, 'ConfidenceIn...       15.0
# 665  {'Hygiene': 10, 'Structural': 10, 'ConfidenceI...       10.0
# 687  {'Hygiene': 15, 'Structural': 15, 'ConfidenceI...       15.0
# 700  {'Hygiene': 10, 'Structural': 10, 'ConfidenceI...       10.0
# 704  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 719  {'Hygiene': 5, 'Structural': 15, 'ConfidenceIn...       15.0
# 752  {'Hygiene': 5, 'Structural': 20, 'ConfidenceIn...       20.0
# 787  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 821  {'Hygiene': 15, 'Structural': 15, 'ConfidenceI...       15.0
# 827  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 828  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 829  {'Hygiene': 5, 'Structural': 15, 'ConfidenceIn...       15.0
# 856  {'Hygiene': 5, 'Structural': 15, 'ConfidenceIn...       15.0
# 863  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 868  {'Hygiene': 15, 'Structural': 5, 'ConfidenceIn...        5.0
# 871  {'Hygiene': 15, 'Structural': 15, 'ConfidenceI...       15.0
# 896  {'Hygiene': 15, 'Structural': 0, 'ConfidenceIn...        0.0
# 912  {'Hygiene': 5, 'Structural': 15, 'ConfidenceIn...       15.0
# 925  {'Hygiene': 10, 'Structural': 10, 'ConfidenceI...       10.0
# 936  {'Hygiene': 15, 'Structural': 5, 'ConfidenceIn...        5.0
# 954  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
#
#                           _id
# 3    5be545d6c4cc3a0001c61067
# 19   5be545d6c4cc3a0001c61077
# 64   5be545d6c4cc3a0001c610a4
# 85   5be545d6c4cc3a0001c610b9
# 108  5be545d6c4cc3a0001c610d0
# 120  5be545d6c4cc3a0001c610dc
# 127  5be545d6c4cc3a0001c610e3
# 180  5be545d6c4cc3a0001c61118
# 189  5be545d6c4cc3a0001c61121
# 206  5be545d6c4cc3a0001c61132
# 230  5be545d6c4cc3a0001c6114a
# 265  5be545d6c4cc3a0001c6116d
# 272  5be545d6c4cc3a0001c61174
# 273  5be545d6c4cc3a0001c61175
# 276  5be545d6c4cc3a0001c61178
# 292  5be545d6c4cc3a0001c61188
# 327  5be545d6c4cc3a0001c611ab
# 350  5be545d6c4cc3a0001c611c2
# 398  5be545d6c4cc3a0001c611f2
# 426  5be545d6c4cc3a0001c6120e
# 432  5be545d6c4cc3a0001c61214
# 459  5be545d6c4cc3a0001c6122f
# 469  5be545d6c4cc3a0001c61239
# 474  5be545d6c4cc3a0001c6123e
# 518  5be545d6c4cc3a0001c6126a
# 561  5be545d6c4cc3a0001c61295
# 575  5be545d6c4cc3a0001c612a3
# 632  5be545d6c4cc3a0001c612dc
# 648  5be545d6c4cc3a0001c612ec
# 654  5be545d6c4cc3a0001c612f2
# 663  5be545d6c4cc3a0001c612fb
# 665  5be545d6c4cc3a0001c612fd
# 687  5be545d6c4cc3a0001c61313
# 700  5be545d6c4cc3a0001c61320
# 704  5be545d6c4cc3a0001c61324
# 719  5be545d6c4cc3a0001c61333
# 752  5be545d6c4cc3a0001c61354
# 787  5be545d6c4cc3a0001c61377
# 821  5be545d6c4cc3a0001c61399
# 827  5be545d6c4cc3a0001c6139f
# 828  5be545d6c4cc3a0001c613a0
# 829  5be545d6c4cc3a0001c613a1
# 856  5be545d6c4cc3a0001c613bc
# 863  5be545d6c4cc3a0001c613c3
# 868  5be545d6c4cc3a0001c613c8
# 871  5be545d6c4cc3a0001c613cb
# 896  5be545d6c4cc3a0001c613e4
# 912  5be545d6c4cc3a0001c613f4
# 925  5be545d6c4cc3a0001c61401
# 936  5be545d6c4cc3a0001c6140c
# 954  5be545d6c4cc3a0001c6141e
#
# [51 rows x 29 columns]

# %%
# We can also create a DataFrame which has only some columns
three_columns = first_1000[['RatingValue', 'FHRSID', 'PostCode']]

print('DataFrame with COLUMNS only:\n\n', three_columns.head())

# Or some rows
# Print the Dataframe with rows 950 to 960, could be any number of rows
print("\nDataFrame with a selection of ROWS:")
first_1000[950:960]
# Out:
# DataFrame with COLUMNS only:
#
#     RatingValue  FHRSID PostCode
# 0          3.0   90105  PR1 7BE
# 1          5.0  479725  PR1 7BY
# 2          5.0  479676  PR1 3BT
# 3          2.0  135423  PR1 6SR
# 4          5.0  759083      NaN
#
# DataFrame with a selection of ROWS:
#     AddressLine1        AddressLine2 AddressLine3 AddressLine4  \
# 950          NaN        Sherwood Way      Preston          NaN
# 951          NaN        Sherwood Way      Preston          NaN
# 952          NaN     14 Avenham Road      Preston          NaN
# 953          NaN        3 Fylde Road      Preston          NaN
# 954          NaN   171 New Hall Lane      Preston          NaN
# 955          NaN  219 Ribbleton Lane      Preston          NaN
# 956          NaN                 NaN          NaN          NaN
# 957          NaN                 NaN          NaN          NaN
# 958          NaN                 NaN          NaN          NaN
# 959          NaN      Blackpool Road      Preston          NaN
#
#                              BusinessName  \
# 950                        Sherwood Court
# 951         Sherwood Lodge Res. Care Home
# 952                 Shining Stars Nursery
# 953                       Ships & Giggles
# 954                             Shop Rite
# 955                           Sicilia Uno
# 956                   Simply Country & Co
# 957                         Simply Delish
# 958                            Sion House
# 959  Sir Tom Finney Community High School
#
#                             BusinessType BusinessTypeID  \
# 950  Hospitals/Childcare/Caring Premises              5
# 951  Hospitals/Childcare/Caring Premises              5
# 952  Hospitals/Childcare/Caring Premises              5
# 953                    Pub/bar/nightclub           7843
# 954                    Retailers - other           4613
# 955               Takeaway/sandwich shop           7844
# 956              Other catering premises           7841
# 957              Other catering premises           7841
# 958  Hospitals/Childcare/Caring Premises              5
# 959            School/college/university           7845
#
#      ConfidenceInManagement  FHRSID  \
# 950                     0.0   89945
# 951                     0.0   71554
# 952                     5.0  113875
# 953                     5.0   84750
# 954                    10.0  479819
# 955                    10.0  479673
# 956                     5.0  615337
# 957                    10.0  781689
# 958                     5.0  448075
# 959                     5.0   77773
#
#                                                Geocode  \
# 950  {'type': 'Point', 'coordinates': [-2.695381, 5...
# 951  {'type': 'Point', 'coordinates': [-2.695381, 5...
# 952  {'type': 'Point', 'coordinates': [-2.698297, 5...
# 953  {'type': 'Point', 'coordinates': [-2.7099, 53....
# 954  {'type': 'Point', 'coordinates': [-2.677047, 5...
# 955  {'type': 'Point', 'coordinates': [-2.681433, 5...
# 956                                               None
# 957                                               None
# 958                                               None
# 959  {'type': 'Point', 'coordinates': [-2.695976, 5...
#
#                ...             PostCode  RatingDate     RatingKey RatingValue  \
# 950            ...              PR2 9GA  2015-02-26  fhrs_5_en-GB         5.0
# 951            ...              PR2 9GA  2015-02-26  fhrs_5_en-GB         5.0
# 952            ...              PR1 3TH  2016-01-14  fhrs_5_en-GB         5.0
# 953            ...              PR1 2XQ  2015-03-06  fhrs_4_en-GB         4.0
# 954            ...              PR1 5XA  2015-04-14  fhrs_2_en-GB         2.0
# 955            ...              PR1 5DY  2015-03-26  fhrs_3_en-GB         3.0
# 956            ...                  NaN  2015-09-25  fhrs_5_en-GB         5.0
# 957            ...                  NaN  2015-06-22  fhrs_4_en-GB         4.0
# 958            ...                  NaN  2015-09-08  fhrs_5_en-GB         5.0
# 959            ...              PR1 6AU  2014-11-27  fhrs_5_en-GB         5.0
#
#          Region RightToReply SchemeType  \
# 950  north_west          NaN       FHRS
# 951  north_west          NaN       FHRS
# 952  north_west          NaN       FHRS
# 953  north_west          NaN       FHRS
# 954  north_west          NaN       FHRS
# 955  north_west          NaN       FHRS
# 956  north_west          NaN       FHRS
# 957  north_west          NaN       FHRS
# 958  north_west          NaN       FHRS
# 959  north_west          NaN       FHRS
#
#                                                 Scores Structural  \
# 950  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        0.0
# 951  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        0.0
# 952  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        5.0
# 953  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       10.0
# 954  {'Hygiene': 10, 'Structural': 15, 'ConfidenceI...       15.0
# 955  {'Hygiene': 10, 'Structural': 10, 'ConfidenceI...       10.0
# 956  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        5.0
# 957  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        5.0
# 958  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        5.0
# 959  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        5.0
#
#                           _id
# 950  5be545d6c4cc3a0001c6141a
# 951  5be545d6c4cc3a0001c6141b
# 952  5be545d6c4cc3a0001c6141c
# 953  5be545d6c4cc3a0001c6141d
# 954  5be545d6c4cc3a0001c6141e
# 955  5be545d6c4cc3a0001c6141f
# 956  5be545d6c4cc3a0001c61420
# 957  5be545d6c4cc3a0001c61421
# 958  5be545d6c4cc3a0001c61422
# 959  5be545d6c4cc3a0001c61423
#
# [10 rows x 29 columns]

# %% [markdown]
# Using the existing `first_1000` DataFrame, try and create a dataset which outputs the columns FHRSID, PostCode, LocalAuthorityName, with any establishment where `RatingValue < 3`

# %%
# YOUR CODE HERE
three_columns = first_1000[first_1000['RatingValue'] < 3][['FHRSID', 'PostCode', 'LocalAuthorityName']]
print('DataFrame with COLUMNS only:\n\n', three_columns)
# Out:
# DataFrame with COLUMNS only:
#
#       FHRSID PostCode LocalAuthorityName
# 3    135423  PR1 6SR            Preston
# 19   479641  PR1 2XQ            Preston
# 64   335295  PR1 3BT            Preston
# 85   448032  PR1 4DX            Preston
# 108  454884  PR1 1PX            Preston
# 120   51647  PR1 6XH            Preston
# 127  448082  PR1 2XQ            Preston
# 180  369063  PR2 6NH            Preston
# 189   69893  PR1 8JD            Preston
# 206   86973  PR1 1PX            Preston
# 230  637915  PR1 5LD            Preston
# 265  335352  PR1 8RQ            Preston
# 272  121600  PR1 1TS            Preston
# 273  133196  PR2 2DX            Preston
# 276  335380  PR1 7BE            Preston
# 292  335301  PR2 6BU            Preston
# 327  479591  PR1 7AT            Preston
# 350  201373  PR2 2DU            Preston
# 398  629593  PR1 5NU            Preston
# 426  479519  PR1 4SS            Preston
# 432  115804  PR1 5HH            Preston
# 459  479764  PR1 2AR            Preston
# 469  479921  PR1 4ST            Preston
# 474  768229  PR2 1AU            Preston
# 518  137209  PR1 4SU            Preston
# 561  850075  PR1 7JN            Preston
# 575  479767  PR2 1XN            Preston
# 632  201370  PR1 5EA            Preston
# 648  448112  PR1 7JS            Preston
# 654   70877  PR1 5QS            Preston
# 663   97856  PR1 8HJ            Preston
# 665  708327  PR1 7RA            Preston
# 687  335282  PR1 3BQ            Preston
# 700  335364  PR1 3YH            Preston
# 704  726619  PR1 5XA            Preston
# 719  479766  PR1 2EE            Preston
# 752  121893  PR2 6YS            Preston
# 787   92213  PR4 0BJ            Preston
# 821  136094  PR1 6EY            Preston
# 827  670391  PR1 6QY            Preston
# 828   78740  PR2 3XA            Preston
# 829  510354  PR1 2UP            Preston
# 856  479530  PR1 4TA            Preston
# 863  479853  PR1 5RY            Preston
# 868  479778  PR1 5TR            Preston
# 871  108298  PR1 3YH            Preston
# 896  136644  PR1 6QA            Preston
# 912   83211  PR1 5AS            Preston
# 925  335327  PR2 9UP            Preston
# 936   94388  PR1 2AR            Preston
# 954  479819  PR1 5XA            Preston

# %% [markdown]
# A `DataFrame` is an object in the `Pandas` library, but in addition we have the `Series` object, a collection of which makes up the `DataFrame`.
#
# Many of the operations we can perform on a `Series` can also be performed on a `DataFrame`.  It is a `Series` object which we will be using this week.
#
# It is possible to perform an operation on each element in the `Series`, as well as call functions which require all of these such as `mean()`.

# %%
print(first_1000['RatingValue'].head(), '\n')
print(first_1000['RatingValue'].head() * 100, '\n')
print(first_1000['RatingValue'].head() * 23 > 100)
# Out:
# 0    3.0
# 1    5.0
# 2    5.0
# 3    2.0
# 4    5.0
# Name: RatingValue, dtype: float64
#
# 0    300.0
# 1    500.0
# 2    500.0
# 3    200.0
# 4    500.0
# Name: RatingValue, dtype: float64
#
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# Name: RatingValue, dtype: bool

# %% [markdown]
# As well as being a part of a `DataFrame`, it is possible to create a `Series` from a list type object, for example see the code below:

# %%
s = pd.Series([8,6,2,7,9,6])
print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# 0    8
# 1    6
# 2    2
# 3    7
# 4    9
# 5    6
# dtype: int64

# %% [markdown]
# Create a `Series` object `rating_series` which contains the `RatingValue` column from the `first_1000 DataFrame` object.
#
# Then display descriptive statistics from that object (mean, median, mode etc).  You can see the full list of available functions in [the documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html)

# %%
# YOUR CODE HERE
rating_series = pd.Series(first_1000['RatingValue'])
mean = rating_series.mean()
median = rating_series.median()
mode = rating_series.mode()

print(mean)
print(median)
print(mode)
# Out:
# 4.29613733906
# 5.0
# 0    5.0
# dtype: float64

# %% [markdown]
# ## Bokeh Charts
# Bokeh uses Pandas data structures as the basis for its charts.  We will now place the data structure we just generated onto various types of charts.
#
# In Bokeh, there is a class **`Plot`** which is the basis for the visualisations we will consider in more detail next week.  A **`Chart`** is a *subclass* of **`Plot`**, which is designed to allow the generation of common charts with the minimum amount of code.
#
# At its simplest, these charts simply accept an object such as a `DataFrame` or `Series`, and will output a chart.  For example, a simple bar chart looks as follows:

# %%
# To display the chart in the notebook, we need to run this function, otherwise calling 'show' will not work
output_notebook()
# Create a simple bar chart with made up data
bar_chart = Bar(pd.Series([8,6,2,7,9,3]))

# Display the bar chart
show(bar_chart)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b30438eb-ef7b-4efe-903a-93d18a4e710a">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="588fa77e-f10a-4764-8535-6cd4cb35080a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("588fa77e-f10a-4764-8535-6cd4cb35080a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("588fa77e-f10a-4764-8535-6cd4cb35080a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '588fa77e-f10a-4764-8535-6cd4cb35080a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d45664ce-6dbf-4394-8aef-f9a7d55d4d66":{"roots":{"references":[{"attributes":{"plot":{"id":"d693a0c0-c1bf-4957-b578-cc0221d0e7f9","subtype":"Chart","type":"Plot"}},"id":"ba53d34a-a967-427c-8404-afb4d59e8b1c","type":"ResetTool"},{"attributes":{"label":{"value":"0"},"renderers":[{"id":"042411e0-da95-4169-8086-c3dfe401f6ca","type":"GlyphRenderer"}]},"id":"a49321c3-1cdf-4e4a-a998-30c724fcc970","type":"LegendItem"},{"attributes":{},"id":"6d3fcc59-a233-4c4f-8cc0-cfd7d2b4cbd9","type":"CategoricalTickFormatter"},{"attributes":{},"id":"c21e99e7-4101-4a3f-9b30-f660ff201a87","type":"CategoricalTicker"},{"attributes":{"label":{"value":"3"},"renderers":[{"id":"2b5a6809-a02e-411c-96a0-5157cf64ac9e","type":"GlyphRenderer"}]},"id":"90560ad8-e10f-4eda-82a5-43086edf2eac","type":"LegendItem"},{"attributes":{"below":[{"id":"3ebda240-238c-4930-ac66-8bb20800d640","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"dc88df2b-f0fe-42b0-a6eb-1b03ffaa65f1","type":"LinearAxis"}],"renderers":[{"id":"5b5b86b4-0f2c-434b-ba3f-a0cc29dc1e34","type":"BoxAnnotation"},{"id":"042411e0-da95-4169-8086-c3dfe401f6ca","type":"GlyphRenderer"},{"id":"e2344713-f215-4ff1-acd4-08a47ec8eb3f","type":"GlyphRenderer"},{"id":"3cc2a9ad-bbcc-418b-8df8-56c966eb9767","type":"GlyphRenderer"},{"id":"2b5a6809-a02e-411c-96a0-5157cf64ac9e","type":"GlyphRenderer"},{"id":"98ccdf5b-da04-4924-8ce1-4b1ed1520e3d","type":"GlyphRenderer"},{"id":"84a075c1-ad05-41cf-9165-7fa830f7274c","type":"GlyphRenderer"},{"id":"3208054d-164e-4d17-b784-ca782a3bb5bf","type":"Legend"},{"id":"3ebda240-238c-4930-ac66-8bb20800d640","type":"CategoricalAxis"},{"id":"dc88df2b-f0fe-42b0-a6eb-1b03ffaa65f1","type":"LinearAxis"},{"id":"0f1f986f-ccf0-44ef-867b-904786cd03bf","type":"Grid"}],"title":{"id":"54ce0798-4891-439c-a9e9-4b92ff6a04a2","type":"Title"},"tool_events":{"id":"a91deae1-fca3-4348-9714-4db0d48c0480","type":"ToolEvents"},"toolbar":{"id":"1e9bcac2-b24e-41ad-8ba4-429acad9cfbc","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"5ea5c2d7-2d1c-4a71-8fa4-daad79154677","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"0f8f46c5-bf1a-4042-8bd1-8077b3415b74","type":"Range1d"}},"id":"d693a0c0-c1bf-4957-b578-cc0221d0e7f9","subtype":"Chart","type":"Plot"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fb2e62b0-3d20-4f14-8abb-d03a34a9e9e6","type":"Rect"},{"attributes":{"dimension":1,"plot":{"id":"d693a0c0-c1bf-4957-b578-cc0221d0e7f9","subtype":"Chart","type":"Plot"},"ticker":{"id":"13366e7b-7a2b-48ab-ba3c-682ae51a6e6b","type":"BasicTicker"}},"id":"0f1f986f-ccf0-44ef-867b-904786cd03bf","type":"Grid"},{"attributes":{"data_source":{"id":"d654c5ca-7bef-4f94-9de2-09ff0bceafa2","type":"ColumnDataSource"},"glyph":{"id":"109c36a5-d6c8-44f2-8c2b-834ca1973fe7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3cc2a9ad-bbcc-418b-8df8-56c966eb9767","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":null},"id":"54ce0798-4891-439c-a9e9-4b92ff6a04a2","type":"Title"},{"attributes":{},"id":"13366e7b-7a2b-48ab-ba3c-682ae51a6e6b","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ce7337c6-ff0b-4e4b-aae8-6dba02fa7c20","type":"PanTool"},{"id":"32a29dcf-9ab7-44b8-8506-bb42beef9bb4","type":"WheelZoomTool"},{"id":"85bb3620-e54c-4650-b3e1-af9b003a4714","type":"BoxZoomTool"},{"id":"3b2154dd-d546-4be2-b3ec-4dba250b0e48","type":"SaveTool"},{"id":"ba53d34a-a967-427c-8404-afb4d59e8b1c","type":"ResetTool"},{"id":"ccc8025f-d0ce-4911-910b-e73ca1f16c48","type":"HelpTool"}]},"id":"1e9bcac2-b24e-41ad-8ba4-429acad9cfbc","type":"Toolbar"},{"attributes":{"label":{"value":"5"},"renderers":[{"id":"84a075c1-ad05-41cf-9165-7fa830f7274c","type":"GlyphRenderer"}]},"id":"4002a9c5-4d9d-471b-97c0-9ec2e38e534b ...

# %% [markdown]
# There are other charts which you can use such as a Histogram, Line graph, and scatter plot.  View the Bokeh **[user guide for charts](http://bokeh.pydata.org/en/latest/docs/reference/charts.html)** to see the options available to customise the chart created above.  In addition it is possible to customise the display.

# %% [markdown]
# # Randomness
#
# A feature which NumPy supports is that of generating random numbers.  This is important, for example, in generating a random sample from a population.  The randomness, however, is not _truly_ random, but rather pseudo-random, i.e., it will generate predictable values based on the initial _seed_ that it accepts.
#
# This feature means that if we know the seed, we can reproduce the results we wish to share provided that we have the same data, which is a desirable property. Though this may sound counter-intuitive it allows others to run our code using the same seed and they will get the same output, the code can then be run using a different seed value.
#
# Consider the scenario where you want to populate an array with random data, you can use the `numpy.random.randint` function as below:

# %%
# import numpy.random
import numpy as np
# The numbers generated will include the low value
low = 0
# The numbers generated will not include the high value, but will go up to high - 1
high = 10
np.random.randint(low, high, size=10)
# Out:
# array([0, 2, 6, 7, 8, 7, 6, 5, 1, 9])

# %% [markdown]
# Create a loop with 10 iterations, where each iteration prints a randomly generated array of size 10.  Notice how each array has set of different values.

# %%
# YOUR CODE HERE
for ri in range(0,10):
    print(np.random.randint(low, high, size=10))
# Out:
# [7 7 8 1 3 1 5 1 0 3]
# [5 2 3 2 7 8 3 7 2 6]
# [9 5 5 0 8 1 8 5 3 2]
# [0 8 1 7 8 2 1 8 3 4]
# [7 4 8 8 5 0 6 8 3 6]
# [0 5 2 2 8 2 7 8 1 8]
# [8 5 2 3 9 7 5 0 3 2]
# [6 4 3 6 4 8 7 0 2 5]
# [5 1 0 3 1 6 4 5 5 8]
# [4 6 3 5 1 0 6 4 1 9]

# %% [markdown]
# For many situations, this is desirable.  However, where we want to be able to reproduce, e.g., sample sizes, we want our samples to be reproducible.  To do this, we use the `RandomState` class in NumPy, where we specify our seed, as follows:

# %%
# Run this cell several times - observe the outcome
rs = np.random.RandomState(543210)
j = rs.randint(low, high, size=10)
print(j)
# Out:
# [8 4 1 0 7 6 4 6 8 3]

# %% [markdown]
# In the cell below, generate the same loop as before, except this time instantiate the `RandomState` object to a value of 123456:

# %%
# YOUR CODE HERE
rs = np.random.RandomState(123456)
j = rs.randint(low, high, size=10)
print(j)
# Out:
# [1 2 1 8 0 7 4 8 4 2]

# %% [markdown]
# # IQR and Outliers
#
# In the videos, Sergej talked about "outliers" in a dataset.  In this worksheet, we'll give a slightly more detailed definition about what exactly they are, and the effect they can have on data.
#
# An outlier is a value which is atypical of the rest of the dataset.  For example, consider this set of data from [searches on the UK income tax calculator](https://www.incometaxcalculator.org.uk/average-salary-uk.php).  If we draw a distribution of them, we will notice a big difference in the values:

# %%
import pandas as pd
import numpy as np
from bokeh.charts import Histogram, output_notebook, show
from bokeh.models import Axis

salaries_list =  [30000,18000,25000,20000,40000,50000,35000,45000,22000,60000,24000,28000,23000,
             16000,100000,21000,26000,15000,32000,19000,17000,70000,27000,55000,18500,80000,
             36000,65000,42000,38000,12000,2481300,75000,33000,19500,43000,48000,120000,14000,
             17500,90000,34000,29000,16500,11000,31000,150000,37000,13000,22500,52000,10000,85000,
             44000,200000,39000,46000,110000,27500,21500,47000,23500,15500,41000,26500,15600,16800,
             20500,14500,130000,250000,24500,28500,72000,140000,32500,8000,53000,95000,25500]


salaries = pd.DataFrame({'Salaries': salaries_list})
print('the max is %f' % (salaries.max()))

from bokeh.plotting import figure, show, output_file
output_notebook()
hist = Histogram(salaries, bins=50)
# Show absolute number on axis rather than E notation:
xaxis = hist.select(dict(type=Axis))[0]
xaxis.formatter.use_scientific = False
show(hist)
# Out:
# the max is 2481300.000000
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5d6d8060-9674-46cd-b7ad-b78904f70049">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2d962015-3f31-42ac-8a05-239f95d670d9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("2d962015-3f31-42ac-8a05-239f95d670d9").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2d962015-3f31-42ac-8a05-239f95d670d9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2d962015-3f31-42ac-8a05-239f95d670d9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"47d572e8-c4ac-40a7-9f2b-5e1385523f9f":{"roots":{"references":[{"attributes":{"data_source":{"id":"a09cec95-3bac-466e-954c-f546dedaa231","type":"ColumnDataSource"},"glyph":{"id":"5498e987-d94f-460d-8469-4403fd3e3692","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0b68f595-e6d8-49ca-84a9-fc485f575ad8","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","color","label","width","fill_alpha","line_alpha","line_color","height"],"data":{"chart_index":["(799456.000000, 848922.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(799456.000000, 848922.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[49466.0],"x":["824189.0"],"y":[0.0]}},"id":"e722d4d3-af07-44a2-8996-0848e40f4778","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ff059ad0-dece-4ad5-b13b-cf1047d0a24e","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","color","label","width","fill_alpha","line_alpha","line_color","height"],"data":{"chart_index":["(2332902.000000, 2382368.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(2332902.000000, 2382368.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[49466.0],"x":["2357635.0"],"y":[0.0]}},"id":"777556e0-7e99-40c0-9839-93fef7bd794f","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","color","label","width","fill_alpha","line_alpha","line_color","height"],"data":{"chart_index":["(1590912.000000, 1640378.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(1590912.000000, 1640378.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[49466.0],"x":["1615645.0"],"y":[0.0]}},"id":"effa45f9-0f7c-44c5-bdb4-e647cf5cf85b","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3b4c277e-d002-46e0-9f13-ced1c5feb8dc","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dea71979-3544-473d-99bd-03f3f4e4de46","type":"Rect"},{"attributes":{"plot":{"id":"3adb9f5a-9c0d-47f9-b2bb-c35aa797c186","subtype":"Chart","type":"Plot"}},"id":"931bcdf1-6bd4-431b-887a-d21959bdf503","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y","color","label","width","fill_alpha","line_alpha","line_color","height"],"data":{"chart_index":["(1244650.000000, 1294116.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(1244650.000000, 1294116.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[49466.0],"x":["1269383.0"],"y":[0.0]}},"id":"bc0e6f9d-13ce-423b-912e-89423d6ebaf8","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"075fe1ff-4c50-4ceb-8f5c-11d4aacbdb13","type":"Rect"},{"attributes":{"plot":{"id":"3adb9f5a-9c0d-47f9-b2bb-c35aa797c186","subtype":"Chart","type":"Plot"}},"id":"b9d6058d-e8f6-44aa-ba32-02bcc05cd8f0","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y","color","label","width","fill_alpha","line_alpha","line_color","height"],"data":{"chart_index":["(502660.000000, 552126.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(502660.000000, 552126.000000]"],"line_alpha":[1.0 ...

# %% [markdown]
# You will notice, the massive outlier on the right, where the person in question earns nearly £2.5 million.  It makes it very difficult to get the chart to display anything useful, and has a significant effect on our data. For example, see the code below which shows the difference in number between the mean and the median:

# %%
print('The mean is: %f, and the median is %f' % 
      (salaries.mean(), salaries.median()))
# Out:
# The mean is: 76371.250000, and the median is 31500.000000

# %% [markdown]
# Task: Remove the highest value from the dataset and see how this changes the mean and the median.

# %%
# YOUR CODE HERE
salaries = salaries.loc[salaries['Salaries'] < 2000000]
print('The mean is: %f, and the median is %f' % (salaries.mean(), salaries.median()))
# Out:
# The mean is: 45929.113924, and the median is 31000.000000

# %% [markdown]
# Moving the top value had a considerable effect on the mean value of the dataset, decreasing it by over £30,000, however the result is still quite a bit higher than the median.  So although the £2.5 million figure is obviously an outlier, how can we define an outlier more concretely?  To start, we will consider the interquartile range (IQR):
#
# ## IQR
#
# The IQR is calculated as follows:
#
# 1. Ordering the data by value
#
# 2. Taking the middle value from the _bottom_ half of the data (lower quartile, known as Q1)
#
# 3. The median is known as Q2
#
# 3. Taking the middle value from the _top_ half of the data (upper quartile, known as Q3)
#
# 4. The IQR is then calculated with Q3 - Q1
#
# The Q1 and Q2 values are considered as the 25th and 75th percentiles, since they represent the values 25% and 75% through the ordered data.  Luckily, there are functions within Pandas which allow the calculation of these percentiles, which provide us with the IQR: the [`quantile`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.quantile.html) function on a `DataFrame` which takes a float between 0 and 1 to get the appropriate percentile.  For example, the median could be calculated as follows:

# %%
salaries.quantile(0.5)
# Out:
# Salaries    31000.0
# Name: 0.5, dtype: float64

# %% [markdown]
# Task: Calculate the IQR of the salaries data using Pandas.  Print out the value of the upper and lower quartiles so you can check the answer is correct

# %%
# YOUR CODE HERE
upper = float(salaries.quantile(0.75))
lower = float(salaries.quantile(0.25))
iqr = upper - lower
print('Upper quartile:\t%f\nLower quartile:\t%f\nIQR:\t\t%f' % (upper, lower, iqr))
# Out:
# Upper quartile:	51000.000000
# Lower quartile:	20250.000000
# IQR:		30750.000000

# %% [markdown]
# ## Outliers
#
# Having introduced the IQR, we can now consider what constitues an outlier.  As a rule of thumb, an outlier can be defined as follows:
#
# - `lower_quartile - (1.5 * IQR)`
# - `upper_quartile + (1.5 * IQR)`
#
# This is highly dependent on the data, and may not be appropriate for all situations, as is the decision of what to do with them.  For the time being, we will simply exclude data which are outside these limits.
#
# To do this, consider the following Pandas code, which excludes outliers from the salaries data.  It uses a more complicated `.loc`, where it filters on two

# %%
# You don't need to write anything here
# Create the dataset again, rather than use the one with the top value taken out
salaries = pd.DataFrame({'Salaries': salaries_list})

salaries = salaries['Salaries'][(salaries['Salaries'] > (float(lower) - (iqr * 1.5)))
                     & (salaries['Salaries'] < (float(upper) + (iqr * 1.5)))]

# salaries = salaries['Salaries'] < lower
# salaries = salaries.loc[salaries['Salaries'] <= lower]
print('The mean is: %f, and the median is %f' % (salaries.mean(), salaries.median()))
# Out:
# The mean is: 34202.816901, and the median is 28000.000000

# %% [markdown]
# The purpose of this exercise was to introduce the concept of an outlier, and how much of an effect it can have on data, and to give some practice using Pandas.  There are many different ways that outliers could be defined, and circumstances where they could or should not be excluded.
